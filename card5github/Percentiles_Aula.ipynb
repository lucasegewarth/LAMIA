# %% [markdown]
# # Percentiles

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

vals = np.random.normal(0, 0.5, 10000)

plt.hist(vals, 50)
plt.show()

# %%
np.percentile(vals, 50)
# Out:
# np.float64(0.003183899851858455)

# %%
np.percentile(vals, 90)
# Out:
# np.float64(0.6467082556613171)

# %%
np.percentile(vals, 20)
# Out:
# np.float64(-0.4141480124225731)

# %% [markdown]
# ## Activity

# %% [markdown]
# Experiment with different parameters when creating the test data. What effect does it have on the percentiles?

# %% [markdown]
# Experimente diferentes parâmetros ao criar os dados de teste. Que efeito isso tem nos percentis?

# %%
vals = np.random.normal(0, 2, 10000)

plt.hist(vals, 50)
plt.show()

# %%
np.percentile(vals, 50)
# Out:
# np.float64(-0.007198303347263037)

# %% [markdown]
# A partir do quarta casa os valors tende se bem proximos

# %%
np.percentile(vals, 99.9999)
# Out:
# np.float64(8.27082718388036)

# %%
np.percentile(vals, 99.99999)
# Out:
# np.float64(8.275954022777876)

# %%
np.percentile(vals, 99)
# Out:
# np.float64(4.75160231164144)

# %%
np.percentile(vals, 1)
# Out:
# np.float64(-4.666321624559411)

# %%
np.percentile(vals, 0.001)
# Out:
# np.float64(-7.336330648388714)

# %%
np.percentile(vals, 0.0001)
# Out:
# np.float64(-7.357792003935141)

# %%
np.percentile(vals, 0.00001)
# Out:
# np.float64(-7.359938139489783)
