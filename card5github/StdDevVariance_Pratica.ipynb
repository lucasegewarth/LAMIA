# %% [markdown]
# Este arquivo é destinado a textes, demontração e praticas referentes as aulas

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

incomes = np.random.normal(5000.0, 1250.0, 100000)

plt.hist(incomes, 500)
plt.show()

# %%
incomes.std() # calcula o desvio padrão dos valores contidos no array income
# Out:
# 1246.1203294279037

# %%
incomes.var() # calcula a variância do conjunto de dados armazenado no array incomes
# Out:
# 1552815.875413507
