# %% [markdown]
# # Examples of Data Distributions

# %% [markdown]
# ## Uniform Distribution
# ## Distribuição Uniforme

# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt

values = np.random.uniform(-10.0, 10.0, 100000)
plt.hist(values, 50)
plt.show()

# %% [markdown]
# ## Normal / Gaussian
# ## Normal / Gaussiano

# %% [markdown]
# Visualize the probability density function:

# %% [markdown]
# Visualize a função de densidade de probabilidade:

# %%
from scipy.stats import norm
import matplotlib.pyplot as plt

x = np.arange(-3, 3, 0.001)
plt.plot(x, norm.pdf(x))

# %% [markdown]
# Generate some random numbers with a normal distribution. "mu" is the desired mean, "sigma" is the standard deviation:

# %% [markdown]
# Gere alguns números aleatórios com distribuição normal. "mu" é a média desejada, "sigma" é o desvio padrão:

# %%
import numpy as np
import matplotlib.pyplot as plt

mu = 5.0
sigma = 2.0
values = np.random.normal(mu, sigma, 10000)
plt.hist(values, 50)
plt.show()

# %% [markdown]
# ## Exponential PDF / "Power Law"
# ## PDF Exponencial / "Lei da Potência"

# %%
from scipy.stats import expon
import matplotlib.pyplot as plt

x = np.arange(0, 10, 0.001)
plt.plot(x, expon.pdf(x))

# %% [markdown]
# ## Binomial Probability Mass Function
# ## Função de massa de probabilidade binomial

# %%
from scipy.stats import binom
import matplotlib.pyplot as plt

n, p = 10, 0.5
x = np.arange(0, 10, 0.001)
plt.plot(x, binom.pmf(x, n, p))

# %% [markdown]
# ## Poisson Probability Mass Function
# ## Função de massa de probabilidade de Poisson

# %% [markdown]
# Example: My website gets on average 500 visits per day. What's the odds of getting 550?

# %% [markdown]
# Exemplo: Meu site recebe em média 500 visitas por dia. Quais são as chances de conseguir 550?

# %%
from scipy.stats import poisson
import matplotlib.pyplot as plt

mu = 500
x = np.arange(400, 600, 0.5)
plt.plot(x, poisson.pmf(x, mu))

# %% [markdown]
# ## Pop Quiz!
# ## Questionário pop!

# %% [markdown]
# What's the equivalent of a probability distribution function when using discrete instead of continuous data?

# %% [markdown]
# Qual é o equivalente a uma função de distribuição de probabilidade ao usar dados discretos em vez de contínuos?

# %% [markdown]
# PMF

# %%
from scipy.stats import binom
import matplotlib.pyplot as plt

n, p = 20, 0.5
x = np.arange(0, 20, 0.001)
plt.plot(x, binom.pmf(x, n, p))
