# %% [markdown]
# # Standard Deviation and Variance

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

incomes = np.random.normal(100.0, 50.0, 10000)

plt.hist(incomes, 50)
plt.show()

# %%
incomes.std()
# Out:
# np.float64(50.22706190806328)

# %%
incomes.var()
# Out:
# np.float64(2522.757747916421)

# %% [markdown]
# ## Activity

# %% [markdown]
# Experiment with different parameters on the normal function, and see what effect it has on the shape of the distribution. How does that new shape relate to the standard deviation and variance?
#
# Tradução: Experimente diferentes parâmetros na função normal e veja que efeito isso tem na forma da distribuição. Como essa nova forma se relaciona com o desvio padrão e a variância?

# %%
incomes = np.random.normal(200.0, 150.0, 10000)

plt.hist(incomes, 150)
plt.show()

# %%
incomes.std()
# Out:
# np.float64(149.45159297409768)

# %%
incomes.var()
# Out:
# np.float64(22335.77864249536)

# %%
incomes = np.random.normal(6000.0, 2000.0, 10000)

plt.hist(incomes, 400)
plt.show()

# %%
incomes.std()
# Out:
# np.float64(1998.4214288806477)

# %%
incomes.var()
# Out:
# np.float64(3993688.2074093698)
