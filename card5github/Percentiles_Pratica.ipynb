# %% [markdown]
# Arquivo destinado a textes e maluquices

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

vals = np.random.normal(0, 0.8, 100000)

plt.hist(vals, 50)
plt.show()

# %%
np.percentile(vals, 50)
# Out:
# 0.003465563599759235

# %%
np.percentile(vals, 90)
# Out:
# 1.0170448808647172

# %%
np.percentile(vals, 20)
# Out:
# -0.6732240011242917

# %%
np.percentile(vals, 99.9999)
# Out:
# 3.6467152116756
